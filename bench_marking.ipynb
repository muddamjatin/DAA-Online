# %% [markdown]
# <a href="https://colab.research.google.com/github/muddamjatin/DAA-Online/blob/main/bench_marking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bubble_sort(arr):
	k = len(arr)
	for i in range(k):
		swapped = False
		for j in range(0, k - i - 1):
			if arr[j] > arr[j + 1]:
				arr[j], arr[j + 1] = arr[j + 1], arr[j]
				swapped = True
		if not swapped:
			break
	return arr

x=bubble_sort([55,45,35,25,15])
print(x)
# Out:
# [15, 25, 35, 45, 55]

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        const = arr[i]
        j = i - 1
        while j >= 0 and const < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = const
    return arr

x=insertion_sort([55,45,35,25,15])
print(x)
# Out:
# [15, 25, 35, 45, 55]

# %%
def selection_sort(arr):
    for i in range(len(arr)):
        mini = i
        for j in range(i + 1, len(arr)):
            if arr[j] < arr[mini]:
                mini = j
        arr[i], arr[mini] = arr[mini], arr[i]
    return arr

x=selection_sort([55,45,35,25,15])
print(x)
# Out:
# [15, 25, 35, 45, 55]

# %%
import timeit
import numpy as np
import matplotlib.pyplot as plt

def benchmark(func, sizes):
    times = []
    for size in sizes:
        arr = np.random.randint(0, 1000, size)
        start_time = timeit.default_timer()
        func(arr.copy())
        end_time = timeit.default_timer()
        times.append(end_time - start_time)
    return times

sizes = [5, 10, 20, 50, 100, 200, 500, 1000, 2000, 5000]
insertion_times = benchmark(insertion_sort, sizes)
selection_times = benchmark(selection_sort, sizes)
bubble_times = benchmark(bubble_sort, sizes)

plt.plot(sizes, insertion_times, label='Insertion Sort')
plt.plot(sizes, selection_times, label='Selection Sort')
plt.plot(sizes, bubble_times, label='Bubble Sort')
plt.xlabel('Input size (n)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.show()
